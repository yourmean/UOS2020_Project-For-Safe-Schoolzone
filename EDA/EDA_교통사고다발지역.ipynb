# %% [markdown]
# ## EDA : 교통사고다발지역
#
# https://www.data.go.kr/data/15003493/fileData.do

# %% [markdown]
# ## 0. 모듈 import 및 전처리

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.read_csv('./도로교통공단_교통사고 다발지역_20200714.csv', encoding='ansi')
df
# Out:
#        사고지역관리번호  사고년도  사고유형구분      위치코드    시도명           시군구명  \
# 0       2013060  2012  스쿨존어린이  11110001  서울특별시     서울특별시 종로구1
# 1       2013060  2012  스쿨존어린이  11290001  서울특별시     서울특별시 성북구1
# 2       2013060  2012  스쿨존어린이  11290002  서울특별시     서울특별시 성북구2
# 3       2013060  2012  스쿨존어린이  11290003  서울특별시     서울특별시 성북구3
# 4       2013060  2012  스쿨존어린이  11320001  서울특별시     서울특별시 도봉구1
# ...         ...   ...     ...       ...    ...            ...
# 11375   2020037  2019     자전거  48129001   경상남도  경상남도 창원시 진해구1
# 11376   2020037  2019     자전거  48170001   경상남도      경상남도 진주시1
# 11377   2020037  2019     자전거  48240001   경상남도      경상남도 사천시1
# 11378   2020037  2019     자전거  48250001   경상남도      경상남도 김해시1
# 11379   2020037  2019     자전거  48250002   경상남도      경상남도 김해시2
#
#                           사고지역위치명  발생건수  사상자수  사망자수  중상자수  경상자수  부상자수  \
# 0          서울특별시 종로구 혜화동(혜화초교 부근)     2     2     0     1     1     0
# 1          서울특별시 성북구 종암동(숭례초교 부근)     2     2     0     0     1     1
# 2       서울특별시 성북구 동소문동7가(정덕초교 부근)     2     2     0     2     0     0
# 3          서울특별시 성북구 석관동(석관초교 부근)     3     3     0     2     1     0
# 4          서울특별시 도봉구 쌍문동(쌍문초교 부근)     2     2     0     0     2     0
# ...                           ...   ...   ...   ...   ...   ...   ...
# 11375  경상남도 창원시 진해구 여좌동(중앙삼거리 부근)     4     4     0     1     3     0
# 11376        경상남도 진주시 칠암동(진양교 부근)     4     4     1     1     2     0
# 11377     경상남도 사천시 동금동(동금2길32 부근)     5     5     0     2     2     1
# 11378      경상남도 김해시 봉황동(가락로13 부근)     5     5     0     3     2     0
# 11379   경상남도 김해시 부원동(김해대로2367 부근)     4     4     0     2     2     0
#
#               위도          경도  \
# 0      37.588413  126.999607
# 1      37.595505  127.035733
# 2      37.597571  127.014564
# 3      37.610429  127.059596
# 4      37.648129  127.024430
# ...          ...         ...
# 11375  35.152311  128.665787
# 11376  35.178908  128.097552
# 11377  34.931136  128.077755
# 11378  35.227932  128.882547
# 11379  35.226660  128.887489
#
#                                              사고다발지역폴리곤정보     데이터기준일자
# 0      {type:Polygon,coordinates:[[[127.002009,37.590...  2020-07-28
# 1      {type:Polygon,coordinates:[[[127.0381354,37.59...  2020-07-28
# 2      {type:Polygon,coordinates:[[[127.0169658,37.59...  2020-07-28
# 3      {type:Polygon,coordinates:[[[127.0619982,37.61...  2020-07-28
# 4      {type:Polygon,coordinates:[[[127.0268336,37.65...  2020-07-28
# ...                                                  ...         ...
# 11375  {type:Polygon,coordinates:[[[128.6675838,35.15...  2020-07-28
# 11376  {type:Polygon,coordinates:[[[128.0993487,35.17...  2020-07-28
# 11377  {type:Polygon,coordinates:[[[128.0795514,34.93...  2020-07-28
# 11378  {type:Polygon,coordinates:[[[128.88434384,35.2...  2020-07-28
# 11379  {type:Polygon,coordinates:[[[128.88928564,35.2...  2020-07-28
#
# [11380 rows x 17 columns]

# %%
df.info() #결측치 없는 좋은 데이터~
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11380 entries, 0 to 11379
# Data columns (total 17 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   사고지역관리번호     11380 non-null  int64
#  1   사고년도         11380 non-null  int64
#  2   사고유형구분       11380 non-null  object
#  3   위치코드         11380 non-null  int64
#  4   시도명          11380 non-null  object
#  5   시군구명         11380 non-null  object
#  6   사고지역위치명      11380 non-null  object
#  7   발생건수         11380 non-null  int64
#  8   사상자수         11380 non-null  int64
#  9   사망자수         11380 non-null  int64
#  10  중상자수         11380 non-null  int64
#  11  경상자수         11380 non-null  int64
#  12  부상자수         11380 non-null  int64
#  13  위도           11380 non-null  float64
#  14  경도           11380 non-null  float64
#  15  사고다발지역폴리곤정보  11380 non-null  object
#  16  데이터기준일자      11380 non-null  object
# dtypes: float64(2), int64(9), object(6)
# memory usage: 1.5+ MB

# %%
df['사고년도'].value_counts() #2020이 없는데..? 일단 진행
# Out:
# 2012    1758
# 2015    1607
# 2013    1606
# 2014    1593
# 2016    1420
# 2017    1265
# 2018    1116
# 2019    1015
# Name: 사고년도, dtype: int64

# %%
df['사고유형구분'].value_counts() #보행존&스쿨존 어린이 분리하자
# Out:
# 보행노인      4480
# 자전거       3645
# 무단횡단      2006
# 보행어린이      934
# 스쿨존어린이     315
# Name: 사고유형구분, dtype: int64

# %%
df[df['시군구명']=='서울특별시 종로구1'] #위경도에 0.01 이하의 아주 미세한 차이(종로구 기준) > 서울로 묶어서 빼자
# Out:
#        사고지역관리번호  사고년도  사고유형구분      위치코드    시도명        시군구명  \
# 0       2013060  2012  스쿨존어린이  11110001  서울특별시  서울특별시 종로구1
# 233     2013098  2012    보행노인  11110001  서울특별시  서울특별시 종로구1
# 741     2013099  2012     자전거  11110001  서울특별시  서울특별시 종로구1
# 1785    2014105  2013    보행노인  11110001  서울특별시  서울특별시 종로구1
# 2817    2014110  2013   보행어린이  11110001  서울특별시  서울특별시 종로구1
# 3407    2015046  2014     자전거  11110001  서울특별시  서울특별시 종로구1
# 3993    2015048  2014    보행노인  11110001  서울특별시  서울특별시 종로구1
# 5117    2016146  2015    보행노인  11110001  서울특별시  서울특별시 종로구1
# 5723    2016147  2015     자전거  11110001  서울특별시  서울특별시 종로구1
# 6320    2016152  2015    무단횡단  11110001  서울특별시  서울특별시 종로구1
# 6564    2017026  2016  스쿨존어린이  11110001  서울특별시  서울특별시 종로구1
# 6702    2017029  2016    보행노인  11110001  서울특별시  서울특별시 종로구1
# 7288    2017050  2016     자전거  11110001  서울특별시  서울특별시 종로구1
# 8099    2018029  2017    보행노인  11110001  서울특별시  서울특별시 종로구1
# 8651    2018032  2017     자전거  11110001  서울특별시  서울특별시 종로구1
# 9249    2019034  2018  스쿨존어린이  11110001  서울특별시  서울특별시 종로구1
# 9370    2019036  2018    보행노인  11110001  서울특별시  서울특별시 종로구1
# 9899    2019038  2018     자전거  11110001  서울특별시  서울특별시 종로구1
# 10489   2020027  2019    보행노인  11110001  서울특별시  서울특별시 종로구1
# 11050   2020037  2019     자전거  11110001  서울특별시  서울특별시 종로구1
#
#                                  사고지역위치명  발생건수  사상자수  사망자수  중상자수  경상자수  부상자수  \
# 0                 서울특별시 종로구 혜화동(혜화초교 부근)     2     2     0     1     1     0
# 233       서울특별시 종로구 교북동(독립문_의주로_진출_1 부근)     3     3     0     3     0     0
# 741                서울특별시 종로구 경운동(안국역 부근)     4     4     0     0     3     1
# 1785            서울특별시 종로구 숭인동(아람보습학원 부근)     5     5     0     5     0     0
# 2817   서울특별시 종로구 사직동(매동길-일반국도48호선진입로 부근)     3     3     0     2     1     0
# 3407              서울특별시 종로구 숭인동(동묘앞역 부근)     5     6     0     1     4     1
# 3993               서울특별시 종로구 묘동(낙원상가 부근)     4     4     0     3     1     0
# 5117              서울특별시 종로구 관수동(종로3가 부근)    10    11     1     4     5     1
# 5723            서울특별시 종로구 청운동(자하문사거리 부근)     5     5     0     2     2     1
# 6320            서울특별시 종로구 창신동(아람보습학원 부근)    11    11     1     6     3     1
# 6564              서울특별시 종로구 숭인동(창신초교 부근)     2     2     0     0     1     1
# 6702             서울특별시 종로구 종로2가(종로3가 부근)     9    12     1     4     7     0
# 7288             서울특별시 종로구 종로5가(종로5가 부근)     4     4     0     1     2     1
# 8099             서울특별시 종로구 종로2가(탑골공원 부근)     6     9     0     3     6     0
# 8651        서울특별시 종로구 종로6가(동대문역 1번출구 부근)     6    11     1     3     5     2
# 9249            서울특별시 종로구 혜화동(서울혜화초교 부근)     2     2     0     0     1     1
# 9370            서울특별시 종로구 낙원동(낙원지하상가 부근)     9     9     0     7     1     1
# 9899          서울특별시 종로구 종로6가(흥인지문사거리 부근)     4     5     0     1     1     3
# 10489             서울특별시 종로구 낙원동(기업은행 부근)     7     7     0     3     3     1
# 11050           서울특별시 종로구 서린동(종로구청입구 부근)     5     5     0     2     3     0
#
#               위도          경도  \
# 0      37.588413  126.999607
# 233    37.571937  126.960630
# 741    37.576533  126.985544
# 1785   37.573370  127.017959
# 2817   37.576041  126.969076
# 3407   37.573635  127.015189
# 3993   37.572648  126.989552
# 5117   37.570193  126.991031
# 5723   37.592486  126.966082
# 6320   37.573658  127.017048
# 6564   37.576610  127.015572
# 6702   37.570517  126.991310
# 7288   37.570890  127.003364
# 8099   37.570390  126.988251
# 8651   37.571758  127.010553
# 9249   37.589740  126.998805
# 9370   37.572581  126.987729
# 9899   37.571229  127.009172
# 10489  37.570203  126.989062
# 11050  37.569908  126.979382
#
#                                              사고다발지역폴리곤정보     데이터기준일자
# 0      {type:Polygon,coordinates:[[[127.002009,37.590...  2020-07-28
# 233    {type:Polygon,coordinates:[[[126.9622309,37.57...  2020-07-28
# 741    {type:Polygon,coordinates:[[[126.9871445,37.57...  2020-07-28
# 1785   {type:Polygon,coordinates:[[[127.0195594,37.57...  2020-07-28
# 2817   {type:Polygon,coordinates:[[[126.9706765,37.57...  2020-07-28
# 3407   {type:Polygon,coordinates:[[[127.0167898,37.57...  2020-07-28
# 3993   {type:Polygon,coordinates:[[[126.9911526,37.57...  2020-07-28
# 5117   {type:Polygon,coordinates:[[[126.9928278,37.57...  2020-07-28
# 5723   {type:Polygon,coordinates:[[[126.96787817,37.5...  2020-07-28
# 6320   {type:Polygon,coordinates:[[[127.0197429,37.57...  2020-07-28
# 6564   {type:Polygon,coordinates:[[[127.01826665,37.5...  2020-07-28
# 6702   {type:Polygon,coordinates:[[[126.99310631,37.5...  2020-07-28
# 7288   {type:Polygon,coordinates:[[[127.00516027,37.5...  2020-07-28
# 8099   {type:Polygon,coordinates:[[[126.99004733,37.5...  2020-07-28
# 8651   {type:Polygon,coordinates:[[[127.01234916,37.5...  2020-07-28
# 9249   {type:Polygon,coordinates:[[[127.00149943,37.5...  2020-07-28
# 9370   {type:Polygon,coordinates:[[[126.98952522,37.5...  2020-07-28
# 9899   {type:Polygon,coordinates:[[[127.01096848,37.5...  2020-07-28
# 10489  {type:Polygon,coordinates:[[[126.99085863,37.5...  2020-07-28
# 11050  {type:Polygon,coordinates:[[[126.98117904,37.5...  2020-07-28

# %%
seoul = df[df['시도명']=='서울특별시']
seoul.reset_index(inplace=True)
seoul
# Out:
#       index  사고지역관리번호  사고년도  사고유형구분      위치코드    시도명        시군구명  \
# 0         0   2013060  2012  스쿨존어린이  11110001  서울특별시  서울특별시 종로구1
# 1         1   2013060  2012  스쿨존어린이  11290001  서울특별시  서울특별시 성북구1
# 2         2   2013060  2012  스쿨존어린이  11290002  서울특별시  서울특별시 성북구2
# 3         3   2013060  2012  스쿨존어린이  11290003  서울특별시  서울특별시 성북구3
# 4         4   2013060  2012  스쿨존어린이  11320001  서울특별시  서울특별시 도봉구1
# ...     ...       ...   ...     ...       ...    ...         ...
# 3164  11179   2020037  2019     자전거  11740004  서울특별시  서울특별시 강동구4
# 3165  11180   2020037  2019     자전거  11740005  서울특별시  서울특별시 강동구5
# 3166  11181   2020037  2019     자전거  11740006  서울특별시  서울특별시 강동구6
# 3167  11182   2020037  2019     자전거  11740007  서울특별시  서울특별시 강동구7
# 3168  11183   2020037  2019     자전거  11740008  서울특별시  서울특별시 강동구8
#
#                            사고지역위치명  발생건수  사상자수  사망자수  중상자수  경상자수  부상자수  \
# 0           서울특별시 종로구 혜화동(혜화초교 부근)     2     2     0     1     1     0
# 1           서울특별시 성북구 종암동(숭례초교 부근)     2     2     0     0     1     1
# 2        서울특별시 성북구 동소문동7가(정덕초교 부근)     2     2     0     2     0     0
# 3           서울특별시 성북구 석관동(석관초교 부근)     3     3     0     2     1     0
# 4           서울특별시 도봉구 쌍문동(쌍문초교 부근)     2     2     0     0     2     0
# ...                            ...   ...   ...   ...   ...   ...   ...
# 3164        서울특별시 강동구 천호동(천호시장 부근)     4     4     1     0     3     0
# 3165         서울특별시 강동구 천호동(구강사 부근)     4     4     0     2     2     0
# 3166      서울특별시 강동구 둔촌동(둔촌고교입구 부근)     4     4     0     2     2     0
# 3167  서울특별시 강동구 천호동(올림픽대로구천면길램 부근)     4     5     0     2     0     3
# 3168        서울특별시 강동구 성내동(둔촌동역 부근)     4     4     0     1     3     0
#
#              위도          경도  \
# 0     37.588413  126.999607
# 1     37.595505  127.035733
# 2     37.597571  127.014564
# 3     37.610429  127.059596
# 4     37.648129  127.024430
# ...         ...         ...
# 3164  37.539221  127.129765
# 3165  37.545050  127.128910
# 3166  37.535601  127.145697
# 3167  37.547237  127.120388
# 3168  37.528430  127.136321
#
#                                             사고다발지역폴리곤정보     데이터기준일자
# 0     {type:Polygon,coordinates:[[[127.002009,37.590...  2020-07-28
# 1     {type:Polygon,coordinates:[[[127.0381354,37.59...  2020-07-28
# 2     {type:Polygon,coordinates:[[[127.0169658,37.59...  2020-07-28
# 3     {type:Polygon,coordinates:[[[127.0619982,37.61...  2020-07-28
# 4     {type:Polygon,coordinates:[[[127.0268336,37.65...  2020-07-28
# ...                                                 ...         ...
# 3164  {type:Polygon,coordinates:[[[127.13156202,37.5...  2020-07-28
# 3165  {type:Polygon,coordinates:[[[127.13070681,37.5...  2020-07-28
# 3166  {type:Polygon,coordinates:[[[127.14749415,37.5...  2020-07-28
# 3167  {type:Polygon,coordinates:[[[127.12218432,37.5...  2020-07-28
# 3168  {type:Polygon,coordinates:[[[127.1381177,37.52...  2020-07-28
#
# [3169 rows x 18 columns]

# %%
skid=seoul[seoul['사고유형구분']==('보행어린이' or '스쿨존어린이')]
skid.reset_index(inplace=True)
skid #서울내 어린이사고지역
# Out:
#      level_0  index  사고지역관리번호  사고년도 사고유형구분      위치코드    시도명        시군구명  \
# 0          9     35   2013097  2012  보행어린이  11170001  서울특별시  서울특별시 용산구1
# 1         10     36   2013097  2012  보행어린이  11200001  서울특별시  서울특별시 성동구1
# 2         11     37   2013097  2012  보행어린이  11215001  서울특별시  서울특별시 광진구1
# 3         12     38   2013097  2012  보행어린이  11215002  서울특별시  서울특별시 광진구2
# 4         13     39   2013097  2012  보행어린이  11260001  서울특별시  서울특별시 중랑구1
# ..       ...    ...       ...   ...    ...       ...    ...         ...
# 147     2889  10417   2020016  2019  보행어린이  11680001  서울특별시  서울특별시 강남구1
# 148     2890  10418   2020016  2019  보행어린이  11710001  서울특별시  서울특별시 송파구1
# 149     2891  10419   2020016  2019  보행어린이  11710002  서울특별시  서울특별시 송파구2
# 150     2892  10420   2020016  2019  보행어린이  11740001  서울특별시  서울특별시 강동구1
# 151     2893  10421   2020016  2019  보행어린이  11740002  서울특별시  서울특별시 강동구2
#
#                         사고지역위치명  발생건수  사상자수  사망자수  중상자수  경상자수  부상자수  \
# 0       서울특별시 용산구 한남동(순천향병원 부근)     3     3     0     0     2     1
# 1       서울특별시 성동구 행당동(무학여고앞 부근)     4     5     0     0     5     0
# 2      서울특별시 광진구 구의동(슬기유치원앞 부근)     3     3     0     2     1     0
# 3       서울특별시 광진구 광장동(광장사거리 부근)     5     5     0     1     3     1
# 4        서울특별시 중랑구 중화동(태능시장 부근)     3     3     0     0     2     1
# ..                          ...   ...   ...   ...   ...   ...   ...
# 147     서울특별시 강남구 대치동(대치사거리 부근)     3     4     0     0     4     0
# 148     서울특별시 송파구 거여동(거마로11 부근)     3     5     0     1     2     2
# 149       서울특별시 송파구 잠실동(신천역 부근)     3     3     0     0     2     1
# 150  서울특별시 강동구 암사동(암사2동주민센터 부근)     4     5     0     0     5     0
# 151      서울특별시 강동구 천호동(천일초교 부근)     3     3     0     0     2     1
#
#             위도          경도                                        사고다발지역폴리곤정보  \
# 0    37.533295  127.005586  {type:Polygon,coordinates:[[[127.0071863,37.53...
# 1    37.558635  127.032724  {type:Polygon,coordinates:[[[127.034325,37.559...
# 2    37.552232  127.093095  {type:Polygon,coordinates:[[[127.0946952,37.55...
# 3    37.544331  127.103648  {type:Polygon,coordinates:[[[127.1052479,37.54...
# 4    37.598100  127.076933  {type:Polygon,coordinates:[[[127.0785348,37.59...
# ..         ...         ...                                                ...
# 147  37.502885  127.058485  {type:Polygon,coordinates:[[[127.06028188,37.5...
# 148  37.494416  127.144762  {type:Polygon,coordinates:[[[127.14655837,37.4...
# 149  37.511498  127.085444  {type:Polygon,coordinates:[[[127.08724046,37.5...
# 150  37.551906  127.126900  {type:Polygon,coordinates:[[[127.12869644,37.5...
# 151  37.543205  127.131640  {type:Polygon,coordinates:[[[127.13343628,37.5...
#
#         데이터기준일자
# 0    2020-07-28
# 1    2020-07-28
# 2    2020-07-28
# 3    2020-07-28
# 4    2020-07-28
# ..          ...
# 147  2020-07-28
# 148  2020-07-28
# 149  2020-07-28
# 150  2020-07-28
# 151  2020-07-28
#
# [152 rows x 19 columns]

# %%
skid['시군구명'].value_counts()
# Out:
# 서울특별시 강서구1     7
# 서울특별시 강동구1     7
# 서울특별시 영등포구1    6
# 서울특별시 동작구1     6
# 서울특별시 강남구1     5
# 서울특별시 양천구1     5
# 서울특별시 은평구1     5
# 서울특별시 성북구1     5
# 서울특별시 송파구1     5
# 서울특별시 중랑구1     5
# 서울특별시 은평구2     4
# 서울특별시 송파구2     4
# 서울특별시 강서구2     4
# 서울특별시 도봉구1     4
# 서울특별시 관악구1     4
# 서울특별시 금천구1     4
# 서울특별시 강북구1     4
# 서울특별시 노원구1     4
# 서울특별시 구로구1     4
# 서울특별시 광진구1     3
# 서울특별시 강동구2     3
# 서울특별시 중랑구2     3
# 서울특별시 성북구2     3
# 서울특별시 동대문구1    3
# 서울특별시 구로구2     3
# 서울특별시 서대문구1    2
# 서울특별시 송파구3     2
# 서울특별시 노원구2     2
# 서울특별시 양천구2     2
# 서울특별시 서초구1     2
# 서울특별시 동작구2     2
# 서울특별시 영등포구2    2
# 서울특별시 동대문구2    2
# 서울특별시 용산구1     2
# 서울특별시 강북구2     2
# 서울특별시 강남구2     2
# 서울특별시 동작구3     1
# 서울특별시 강서구3     1
# 서울특별시 광진구2     1
# 서울특별시 양천구3     1
# 서울특별시 성동구1     1
# 서울특별시 금천구2     1
# 서울특별시 중구1      1
# 서울특별시 마포구1     1
# 서울특별시 중랑구3     1
# 서울특별시 종로구1     1
# 서울특별시 도봉구2     1
# 서울특별시 관악구2     1
# 서울특별시 중구2      1
# 서울특별시 은평구3     1
# 서울특별시 마포구2     1
# 서울특별시 강북구3     1
# 서울특별시 서초구2     1
# 서울특별시 구로구3     1
# 서울특별시 송파구5     1
# 서울특별시 송파구4     1
# Name: 시군구명, dtype: int64

# %%
len(skid['시군구명'].value_counts())
# Out:
# 56

# %%
# 구 정리 하자..
skid['서울구'] = 'a'
# Out:
# C:\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
# 자그마치 25개의 구가 있따......!
skid.loc[skid['시군구명'].str.contains('강남구'), ['서울구']] = '강남구'
skid.loc[skid['시군구명'].str.contains('강동구'), ['서울구']] = '강동구'
skid.loc[skid['시군구명'].str.contains('강서구'), ['서울구']] = '강서구'
skid.loc[skid['시군구명'].str.contains('강북구'), ['서울구']] = '강북구'
skid.loc[skid['시군구명'].str.contains('관악구'), ['서울구']] = '관악구'

skid.loc[skid['시군구명'].str.contains('광진구'), ['서울구']] = '광진구'
skid.loc[skid['시군구명'].str.contains('구로구'), ['서울구']] = '구로구'
skid.loc[skid['시군구명'].str.contains('금천구'), ['서울구']] = '금천구'
skid.loc[skid['시군구명'].str.contains('노원구'), ['서울구']] = '노원구'
skid.loc[skid['시군구명'].str.contains('동대문구'), ['서울구']] = '동대문구'

skid.loc[skid['시군구명'].str.contains('도봉구'), ['서울구']] = '도봉구'
skid.loc[skid['시군구명'].str.contains('동작구'), ['서울구']] = '동작구'
skid.loc[skid['시군구명'].str.contains('마포구'), ['서울구']] = '마포구'
skid.loc[skid['시군구명'].str.contains('서대문구'), ['서울구']] = '서대문구'
skid.loc[skid['시군구명'].str.contains('성동구'), ['서울구']] = '성동구'

skid.loc[skid['시군구명'].str.contains('성북구'), ['서울구']] = '성북구'
skid.loc[skid['시군구명'].str.contains('서초구'), ['서울구']] = '서초구'
skid.loc[skid['시군구명'].str.contains('송파구'), ['서울구']] = '송파구'
skid.loc[skid['시군구명'].str.contains('영등포구'), ['서울구']] = '영등포구'
skid.loc[skid['시군구명'].str.contains('용산구'), ['서울구']] = '용산구'

skid.loc[skid['시군구명'].str.contains('양천구'), ['서울구']] = '양천구'
skid.loc[skid['시군구명'].str.contains('은평구'), ['서울구']] = '은평구'
skid.loc[skid['시군구명'].str.contains('종로구'), ['서울구']] = '종로구'
skid.loc[skid['시군구명'].str.contains('중구'), ['서울구']] = '중구'
skid.loc[skid['시군구명'].str.contains('중랑구'), ['서울구']] = '중랑구'
# Out:
# C:\Anaconda3\lib\site-packages\pandas\core\indexing.py:966: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[item] = s

# %%
len(skid[skid['서울구']=='a']) # 다행히 깔끔하게 처리되었음^_^
# Out:
# 0

# %%
skid
# Out:
#      level_0  index  사고지역관리번호  사고년도 사고유형구분      위치코드    시도명        시군구명  \
# 0          9     35   2013097  2012  보행어린이  11170001  서울특별시  서울특별시 용산구1
# 1         10     36   2013097  2012  보행어린이  11200001  서울특별시  서울특별시 성동구1
# 2         11     37   2013097  2012  보행어린이  11215001  서울특별시  서울특별시 광진구1
# 3         12     38   2013097  2012  보행어린이  11215002  서울특별시  서울특별시 광진구2
# 4         13     39   2013097  2012  보행어린이  11260001  서울특별시  서울특별시 중랑구1
# ..       ...    ...       ...   ...    ...       ...    ...         ...
# 147     2889  10417   2020016  2019  보행어린이  11680001  서울특별시  서울특별시 강남구1
# 148     2890  10418   2020016  2019  보행어린이  11710001  서울특별시  서울특별시 송파구1
# 149     2891  10419   2020016  2019  보행어린이  11710002  서울특별시  서울특별시 송파구2
# 150     2892  10420   2020016  2019  보행어린이  11740001  서울특별시  서울특별시 강동구1
# 151     2893  10421   2020016  2019  보행어린이  11740002  서울특별시  서울특별시 강동구2
#
#                         사고지역위치명  발생건수  사상자수  사망자수  중상자수  경상자수  부상자수  \
# 0       서울특별시 용산구 한남동(순천향병원 부근)     3     3     0     0     2     1
# 1       서울특별시 성동구 행당동(무학여고앞 부근)     4     5     0     0     5     0
# 2      서울특별시 광진구 구의동(슬기유치원앞 부근)     3     3     0     2     1     0
# 3       서울특별시 광진구 광장동(광장사거리 부근)     5     5     0     1     3     1
# 4        서울특별시 중랑구 중화동(태능시장 부근)     3     3     0     0     2     1
# ..                          ...   ...   ...   ...   ...   ...   ...
# 147     서울특별시 강남구 대치동(대치사거리 부근)     3     4     0     0     4     0
# 148     서울특별시 송파구 거여동(거마로11 부근)     3     5     0     1     2     2
# 149       서울특별시 송파구 잠실동(신천역 부근)     3     3     0     0     2     1
# 150  서울특별시 강동구 암사동(암사2동주민센터 부근)     4     5     0     0     5     0
# 151      서울특별시 강동구 천호동(천일초교 부근)     3     3     0     0     2     1
#
#             위도          경도                                        사고다발지역폴리곤정보  \
# 0    37.533295  127.005586  {type:Polygon,coordinates:[[[127.0071863,37.53...
# 1    37.558635  127.032724  {type:Polygon,coordinates:[[[127.034325,37.559...
# 2    37.552232  127.093095  {type:Polygon,coordinates:[[[127.0946952,37.55...
# 3    37.544331  127.103648  {type:Polygon,coordinates:[[[127.1052479,37.54...
# 4    37.598100  127.076933  {type:Polygon,coordinates:[[[127.0785348,37.59...
# ..         ...         ...                                                ...
# 147  37.502885  127.058485  {type:Polygon,coordinates:[[[127.06028188,37.5...
# 148  37.494416  127.144762  {type:Polygon,coordinates:[[[127.14655837,37.4...
# 149  37.511498  127.085444  {type:Polygon,coordinates:[[[127.08724046,37.5...
# 150  37.551906  127.126900  {type:Polygon,coordinates:[[[127.12869644,37.5...
# 151  37.543205  127.131640  {type:Polygon,coordinates:[[[127.13343628,37.5...
#
#         데이터기준일자  서울구
# 0    2020-07-28  용산구
# 1    2020-07-28  성동구
# 2    2020-07-28  광진구
# 3    2020-07-28  광진구
# 4    2020-07-28  중랑구
# ..          ...  ...
# 147  2020-07-28  강남구
# 148  2020-07-28  송파구
# 149  2020-07-28  송파구
# 150  2020-07-28  강동구
# 151  2020-07-28  강동구
#
# [152 rows x 20 columns]

# %%
# 반지름 크기 결정 위한 심각도 피처 생성
skid['심각도'] = skid['발생건수']+skid['사상자수'] + skid['사망자수'] + skid['중상자수'] + skid['경상자수'] + skid['부상자수']
# Out:
# C:\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
skid
# Out:
#      level_0  index  사고지역관리번호  사고년도 사고유형구분      위치코드    시도명        시군구명  \
# 0          9     35   2013097  2012  보행어린이  11170001  서울특별시  서울특별시 용산구1
# 1         10     36   2013097  2012  보행어린이  11200001  서울특별시  서울특별시 성동구1
# 2         11     37   2013097  2012  보행어린이  11215001  서울특별시  서울특별시 광진구1
# 3         12     38   2013097  2012  보행어린이  11215002  서울특별시  서울특별시 광진구2
# 4         13     39   2013097  2012  보행어린이  11260001  서울특별시  서울특별시 중랑구1
# ..       ...    ...       ...   ...    ...       ...    ...         ...
# 147     2889  10417   2020016  2019  보행어린이  11680001  서울특별시  서울특별시 강남구1
# 148     2890  10418   2020016  2019  보행어린이  11710001  서울특별시  서울특별시 송파구1
# 149     2891  10419   2020016  2019  보행어린이  11710002  서울특별시  서울특별시 송파구2
# 150     2892  10420   2020016  2019  보행어린이  11740001  서울특별시  서울특별시 강동구1
# 151     2893  10421   2020016  2019  보행어린이  11740002  서울특별시  서울특별시 강동구2
#
#                         사고지역위치명  발생건수  ...  사망자수  중상자수  경상자수  부상자수         위도  \
# 0       서울특별시 용산구 한남동(순천향병원 부근)     3  ...     0     0     2     1  37.533295
# 1       서울특별시 성동구 행당동(무학여고앞 부근)     4  ...     0     0     5     0  37.558635
# 2      서울특별시 광진구 구의동(슬기유치원앞 부근)     3  ...     0     2     1     0  37.552232
# 3       서울특별시 광진구 광장동(광장사거리 부근)     5  ...     0     1     3     1  37.544331
# 4        서울특별시 중랑구 중화동(태능시장 부근)     3  ...     0     0     2     1  37.598100
# ..                          ...   ...  ...   ...   ...   ...   ...        ...
# 147     서울특별시 강남구 대치동(대치사거리 부근)     3  ...     0     0     4     0  37.502885
# 148     서울특별시 송파구 거여동(거마로11 부근)     3  ...     0     1     2     2  37.494416
# 149       서울특별시 송파구 잠실동(신천역 부근)     3  ...     0     0     2     1  37.511498
# 150  서울특별시 강동구 암사동(암사2동주민센터 부근)     4  ...     0     0     5     0  37.551906
# 151      서울특별시 강동구 천호동(천일초교 부근)     3  ...     0     0     2     1  37.543205
#
#              경도                                        사고다발지역폴리곤정보  \
# 0    127.005586  {type:Polygon,coordinates:[[[127.0071863,37.53...
# 1    127.032724  {type:Polygon,coordinates:[[[127.034325,37.559...
# 2    127.093095  {type:Polygon,coordinates:[[[127.0946952,37.55...
# 3    127.103648  {type:Polygon,coordinates:[[[127.1052479,37.54...
# 4    127.076933  {type:Polygon,coordinates:[[[127.0785348,37.59...
# ..          ...                                                ...
# 147  127.058485  {type:Polygon,coordinates:[[[127.06028188,37.5...
# 148  127.144762  {type:Polygon,coordinates:[[[127.14655837,37.4...
# 149  127.085444  {type:Polygon,coordinates:[[[127.08724046,37.5...
# 150  127.126900  {type:Polygon,coordinates:[[[127.12869644,37.5...
# 151  127.131640  {type:Polygon,coordinates:[[[127.13343628,37.5...
#
#         데이터기준일자  서울구 심각도
# 0    2020-07-28  용산구   9
# 1    2020-07-28  성동구  14
# 2    2020-07-28  광진구   9
# 3    2020-07-28  광진구  15
# 4    2020-07-28  중랑구   9
# ..          ...  ...  ..
# 147  2020-07-28  강남구  11
# 148  2020-07-28  송파구  13
# 149  2020-07-28  송파구   9
# 150  2020-07-28  강동구  14
# 151  2020-07-28  강동구   9
#
# [152 rows x 21 columns]

# %%
skid.to_csv('./skid.csv')

# %%
df = pd.read_csv('./skid.csv')
df
# Out:
#      Unnamed: 0  level_0  index  사고지역관리번호  사고년도 사고유형구분      위치코드    시도명  \
# 0             0        9     35   2013097  2012  보행어린이  11170001  서울특별시
# 1             1       10     36   2013097  2012  보행어린이  11200001  서울특별시
# 2             2       11     37   2013097  2012  보행어린이  11215001  서울특별시
# 3             3       12     38   2013097  2012  보행어린이  11215002  서울특별시
# 4             4       13     39   2013097  2012  보행어린이  11260001  서울특별시
# ..          ...      ...    ...       ...   ...    ...       ...    ...
# 147         147     2889  10417   2020016  2019  보행어린이  11680001  서울특별시
# 148         148     2890  10418   2020016  2019  보행어린이  11710001  서울특별시
# 149         149     2891  10419   2020016  2019  보행어린이  11710002  서울특별시
# 150         150     2892  10420   2020016  2019  보행어린이  11740001  서울특별시
# 151         151     2893  10421   2020016  2019  보행어린이  11740002  서울특별시
#
#            시군구명                     사고지역위치명  ...  사망자수  중상자수  경상자수  부상자수  \
# 0    서울특별시 용산구1     서울특별시 용산구 한남동(순천향병원 부근)  ...     0     0     2     1
# 1    서울특별시 성동구1     서울특별시 성동구 행당동(무학여고앞 부근)  ...     0     0     5     0
# 2    서울특별시 광진구1    서울특별시 광진구 구의동(슬기유치원앞 부근)  ...     0     2     1     0
# 3    서울특별시 광진구2     서울특별시 광진구 광장동(광장사거리 부근)  ...     0     1     3     1
# 4    서울특별시 중랑구1      서울특별시 중랑구 중화동(태능시장 부근)  ...     0     0     2     1
# ..          ...                         ...  ...   ...   ...   ...   ...
# 147  서울특별시 강남구1     서울특별시 강남구 대치동(대치사거리 부근)  ...     0     0     4     0
# 148  서울특별시 송파구1     서울특별시 송파구 거여동(거마로11 부근)  ...     0     1     2     2
# 149  서울특별시 송파구2       서울특별시 송파구 잠실동(신천역 부근)  ...     0     0     2     1
# 150  서울특별시 강동구1  서울특별시 강동구 암사동(암사2동주민센터 부근)  ...     0     0     5     0
# 151  서울특별시 강동구2      서울특별시 강동구 천호동(천일초교 부근)  ...     0     0     2     1
#
#             위도          경도                                        사고다발지역폴리곤정보  \
# 0    37.533295  127.005586  {type:Polygon,coordinates:[[[127.0071863,37.53...
# 1    37.558635  127.032724  {type:Polygon,coordinates:[[[127.034325,37.559...
# 2    37.552232  127.093095  {type:Polygon,coordinates:[[[127.0946952,37.55...
# 3    37.544331  127.103648  {type:Polygon,coordinates:[[[127.1052479,37.54...
# 4    37.598100  127.076933  {type:Polygon,coordinates:[[[127.0785348,37.59...
# ..         ...         ...                                                ...
# 147  37.502885  127.058485  {type:Polygon,coordinates:[[[127.06028188,37.5...
# 148  37.494416  127.144762  {type:Polygon,coordinates:[[[127.14655837,37.4...
# 149  37.511498  127.085444  {type:Polygon,coordinates:[[[127.08724046,37.5...
# 150  37.551906  127.126900  {type:Polygon,coordinates:[[[127.12869644,37.5...
# 151  37.543205  127.131640  {type:Polygon,coordinates:[[[127.13343628,37.5...
#
#         데이터기준일자  서울구 심각도
# 0    2020-07-28  용산구   9
# 1    2020-07-28  성동구  14
# 2    2020-07-28  광진구   9
# 3    2020-07-28  광진구  15
# 4    2020-07-28  중랑구   9
# ..          ...  ...  ..
# 147  2020-07-28  강남구  11
# 148  2020-07-28  송파구  13
# 149  2020-07-28  송파구   9
# 150  2020-07-28  강동구  14
# 151  2020-07-28  강동구   9
#
# [152 rows x 22 columns]

# %% [markdown]
# ## 2. folium 좌표 시각화

# %%
import folium

# %%
# 서울맵 잘나오나?
lon=37.5502
lat=126.982
map_s = folium.Map(location=[lon, lat], zoom_start=11)
map_s
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//rawcdn.githack.com/python-visualization/folium/master/folium/templates/leaflet.awesome.rotate.css%22/%3E%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_ae62b9b32bdb4b57b2a038fa2cbc55d4%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_ae62b9b32bdb4b57b2a038fa2cbc55d4%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_ae62b9b32bdb4b57b2a038fa2cbc55d4%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%22map_ae62b9b32bdb4b57b2a038fa2cbc55d4%22%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20center%3A%20%5B37.5502%2C%20126.982%5D%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20 ...

# %%
# 좌표계정보 임포트
import json
geo_path="./서울시_행정구역_시군구_정보.json" #(좌표계_ WGS1984)
geo_str=json.load(open(geo_path, encoding='utf-8'))

# %% [markdown]
# ## 지도 생성

# %%
# 1. 지도 객체 생성
map_s = folium.Map(location=[37.5502, 126.982], zoom_start=11)
map_s
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//rawcdn.githack.com/python-visualization/folium/master/folium/templates/leaflet.awesome.rotate.css%22/%3E%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_04cb6c26ffaf4929828024ab52c37fb3%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_04cb6c26ffaf4929828024ab52c37fb3%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_04cb6c26ffaf4929828024ab52c37fb3%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%22map_04cb6c26ffaf4929828024ab52c37fb3%22%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20center%3A%20%5B37.5502%2C%20126.982%5D%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20 ...

# %%
# 사고다발지역 위도/경도 표시
lat = skid['위도']
lon = skid['경도']
name = skid['사고지역위치명']

# %% [markdown]
# 마커 아이콘 색상값
#
# ‘lightgreen’, ‘darkgreen’, ‘darkblue’, ‘cadetblue’, ‘orange’, ‘lightred’, ‘darkred’, ‘green’, ‘blue’, ‘black’, ‘lightblue’, ‘white’, ‘lightgray’, ‘red’, ‘pink’, ‘beige’, ‘gray’, ‘purple’, ‘darkpurple’

# %%
type(skid)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# ### 마커 시각화 - 1

# %%
# zoom_start: 배율 1~22
map_osm = folium.Map(location=[37.566651, 126.978428], zoom_start=12)
map_osm

for i in skid.index:
    lat = skid.loc[i, '위도']
    lon = skid.loc[i, '경도']
    name = skid.loc[i, '사고지역위치명']
    
    # 추출한 정보를 지도에 표시
    marker = folium.Marker([lat,lon], popup=name)
    marker.add_to(map_osm)

map_osm
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//rawcdn.githack.com/python-visualization/folium/master/folium/templates/leaflet.awesome.rotate.css%22/%3E%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_d3fcd3cb060347cbaf4f8ad4c17acb26%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_d3fcd3cb060347cbaf4f8ad4c17acb26%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_d3fcd3cb060347cbaf4f8ad4c17acb26%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%22map_d3fcd3cb060347cbaf4f8ad4c17acb26%22%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20center%3A%20%5B37.566651%2C%20126.978428%5D%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20% ...

# %%
#map_osm.save('map_test.html')

# %% [markdown]
# ### 마커 시각화 - 2

# %%
# zoom_start: 배율 1~22
map_osm = folium.Map(location=[37.566651, 126.978428], zoom_start=11.3)
map_osm

for i in skid.index:
    lat = skid.loc[i, '위도']
    lon = skid.loc[i, '경도']
    name = skid.loc[i, '사고지역위치명']
    ser = skid.loc[i, '심각도']
    
    # 추출한 정보를 지도에 표시
    marker = folium.CircleMarker([lat,lon], radius=int(ser), color='#3186cc', fill_color='#3186cc',alpha=1, popup=name)
    marker.add_to(map_osm)

map_osm
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//rawcdn.githack.com/python-visualization/folium/master/folium/templates/leaflet.awesome.rotate.css%22/%3E%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_5433747ec57b48999fae1631c24280bc%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_5433747ec57b48999fae1631c24280bc%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_5433747ec57b48999fae1631c24280bc%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%22map_5433747ec57b48999fae1631c24280bc%22%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20center%3A%20%5B37.566651%2C%20126.978428%5D%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20% ...

# %%
#map_osm.save('map_test2.html')

# %%
#map_s = folium.Map(location=[37.5502, 126.982], zoom_start=11)
#for i in skid.index:
#    folium.Marker([lat[i], lon[i]], popup='region', icon=folium.Icon(color='darkblue')).add_to(map_s)
#map_s

# %%
## 사용자 지정 아이콘 (HTML 팝업)
## 어린이 이모티콘 귀여울 것 같음


# 새로운 지도 객체 생성
map_osm2 = folium.Map(location=[37.502549, 127.024867], zoom_start=17)

# HTML을 사용한 팝업
popup_html = folium.Popup("<font color='green' style='white-space: nowrap'><b>이젠아카데미컴퓨터학원</b></font>", parse_html=False)

# 사용자 지정 아이콘 이미지 사용
icon_img = folium.features.CustomIcon('http://itpaper.co.kr/demo/py/ho.png', icon_size=(50, 50))

# 마커 객체 생성
marker2 = folium.Marker([37.502549, 127.024867], 
                        popup=popup_html,
                        icon=icon_img)

marker2.add_to(map_osm2) # 마커 객체를 지도에 추가함
map_osm2                 # 지도 표시하기
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//rawcdn.githack.com/python-visualization/folium/master/folium/templates/leaflet.awesome.rotate.css%22/%3E%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_72ffd97703cf43af8b16b729da9f626f%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_72ffd97703cf43af8b16b729da9f626f%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_72ffd97703cf43af8b16b729da9f626f%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%22map_72ffd97703cf43af8b16b729da9f626f%22%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20center%3A%20%5B37.502549%2C%20127.024867%5D%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20% ...

# %%
## 원형 마커 (범위 지정)

# 새로운 지도 객체 생성
map_osm3 = folium.Map(location=[37.502549, 127.024867], zoom_start=11)

# 원형마커 
marker3 = folium.CircleMarker([37.502549, 127.024867], 
                              radius=100,                 # 범위
                              color='#3186cc',            # 선 색상
                              fill_color='#3186cc',       # 면 색상
                              popup='이젠아카데미컴퓨터학원')

marker3.add_to(map_osm3)

map_osm3
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//rawcdn.githack.com/python-visualization/folium/master/folium/templates/leaflet.awesome.rotate.css%22/%3E%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_2b9c84894a0f4ccb8785a25cfc2cc5c0%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_2b9c84894a0f4ccb8785a25cfc2cc5c0%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_2b9c84894a0f4ccb8785a25cfc2cc5c0%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%22map_2b9c84894a0f4ccb8785a25cfc2cc5c0%22%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20center%3A%20%5B37.502549%2C%20127.024867%5D%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20% ...

# %%
## 파일로 저장
map_osm3.save('map_osm3.html') #파일이 저장될 위치

# %% [markdown]
# ---
#
# # part2.  전국 초등학교 지점 시각화

# %%
# 이친구는,,, 10000개인 척하는 500개이다.. ^^
#df = pd.read_csv('C:/Users/82104/Desktop/4-2/Untitled Folder/전국초중등학교위치표준데이터.csv', encoding='ansi')
#df

# %%
pre = pd.read_excel("C:/Users/82104/Desktop/4-2/Untitled Folder/school2019.xlsx", encoding='ansi')
pre
# Out:
#              학교ID        학교명 학교급구분        설립일자 설립형태 본교분교구분 운영상태  \
# 0      B000001838   서울휘경초등학교  초등학교  1959-10-10   공립     본교   운영
# 1      B000001839   서울동답초등학교  초등학교  1984-05-23   공립     본교   운영
# 2      B000001840  서울답십리초등학교  초등학교  1962-11-29   공립     본교   운영
# 3      B000001841   서울신답초등학교  초등학교  1972-05-09   공립     본교   운영
# 4      B000001842   서울용두초등학교  초등학교  1948-11-01   공립     본교   운영
# ...           ...        ...   ...         ...  ...    ...  ...
# 11868  B000027396   평택새빛초등학교  초등학교  2019-09-01   공립     본교   운영
# 11869  B000027418     마장초등학교  초등학교  1920-12-04   공립     본교   운영
# 11870  B000027505   인천중산초등학교  초등학교  2019-03-01   공립     본교   운영
# 11871  B000027506    인천중산중학교   중학교  2019-03-01   공립     본교   운영
# 11872  B000027509     해누리중학교   중학교  2019-03-01   공립     본교   운영
#
#                       소재지지번주소               소재지도로명주소  시도교육청코드    시도교육청명  \
# 0        서울특별시 동대문구 휘경동 302-2    서울특별시 동대문구 망우로6길 48  7010000  서울특별시교육청
# 1        서울특별시 동대문구 답십리동 2-24  서울특별시 동대문구 답십리로60길 12  7010000  서울특별시교육청
# 2         서울특별시 동대문구 답십리동 274    서울특별시 동대문구 전농로3길 23  7010000  서울특별시교육청
# 3      서울특별시 동대문구 답십리동 463-13    서울특별시 동대문구 천호대로 177  7010000  서울특별시교육청
# 4        서울특별시 동대문구 용두동 237-1  서울특별시 동대문구 천호대로13길 43  7010000  서울특별시교육청
# ...                       ...                    ...      ...       ...
# 11868      경기도 평택시 칠원동 산36-34   경기도 평택시 신촌2로 33(칠원동)  7530000    경기도교육청
# 11869    경기도 이천시 마장면 오천리 19-1    경기도 이천시 마장면 오천로 130  7530000    경기도교육청
# 11870     인천광역시 중구 중산동 1887-3      인천광역시 중구 두미포로 100  7310000  인천광역시교육청
# 11871     인천광역시 중구 중산동 1914-2      인천광역시 중구 두미포로 189  7310000  인천광역시교육청
# 11872       서울특별시 송파구 가락동 479   서울특별시 송파구 송파대로37길 95  7010000  서울특별시교육청
#
#        교육지원청코드          교육지원청명        생성일자        변경일자         위도          경도  \
# 0      7021000    서울특별시동부교육지원청  2013-11-29  2019-09-10  37.585736  127.058122
# 1      7021000    서울특별시동부교육지원청  2013-11-29  2019-09-10  37.571817  127.064205
# 2      7021000    서울특별시동부교육지원청  2013-11-29  2019-09-10  37.569003  127.055423
# 3      7021000    서울특별시동부교육지원청  2013-11-29  2019-09-10  37.573001  127.043399
# 4      7021000    서울특별시동부교육지원청  2013-11-29  2019-09-10  37.575743  127.028885
# ...        ...             ...         ...         ...        ...         ...
# 11868  7631000      경기도평택교육지원청  2013-11-29  2019-09-10  37.024922  127.105114
# 11869  7741000      경기도이천교육지원청  2013-11-29  2019-09-10  37.246497  127.358475
# 11870  7321000    인천광역시남부교육지원청  2013-11-29  2019-09-10  37.494695  126.565599
# 11871  7321000    인천광역시남부교육지원청  2013-11-29  2019-09-10  37.498222  126.571277
# 11872  7071000  서울특별시강동송파교육지원청  2013-11-29  2019-09-10  37.497612  127.102533
#
#           데이터기준일자   제공기관코드    제공기관명
# 0      2019-09-16  7001220  한국교원대학교
# 1      2019-09-16  7001220  한국교원대학교
# 2      2019-09-16  7001220  한국교원대학교
# 3      2019-09-16  7001220  한국교원대학교
# 4      2019-09-16  7001220  한국교원대학교
# ...           ...      ...      ...
# 11868  2019-09-16  7001220  한국교원대학교
# 11869  2019-09-16  7001220  한국교원대학교
# 11870  2019-09-16  7001220  한국교원대학교
# 11871  2019-09-16  7001220  한국교원대학교
# 11872  2019-09-16  7001220  한국교원대학교
#
# [11873 rows x 20 columns]

# %%
len(pre)
# Out:
# 11873

# %%
# 전처리 쪼꼼 해준다
pre2 = pre.filter(['학교명', '학교급구분', '소재지도로명주소', '시도교육청명' ,'위도', '경도'])
pre2
# Out:
#              학교명 학교급구분               소재지도로명주소    시도교육청명         위도          경도
# 0       서울휘경초등학교  초등학교    서울특별시 동대문구 망우로6길 48  서울특별시교육청  37.585736  127.058122
# 1       서울동답초등학교  초등학교  서울특별시 동대문구 답십리로60길 12  서울특별시교육청  37.571817  127.064205
# 2      서울답십리초등학교  초등학교    서울특별시 동대문구 전농로3길 23  서울특별시교육청  37.569003  127.055423
# 3       서울신답초등학교  초등학교    서울특별시 동대문구 천호대로 177  서울특별시교육청  37.573001  127.043399
# 4       서울용두초등학교  초등학교  서울특별시 동대문구 천호대로13길 43  서울특별시교육청  37.575743  127.028885
# ...          ...   ...                    ...       ...        ...         ...
# 11868   평택새빛초등학교  초등학교   경기도 평택시 신촌2로 33(칠원동)    경기도교육청  37.024922  127.105114
# 11869     마장초등학교  초등학교    경기도 이천시 마장면 오천로 130    경기도교육청  37.246497  127.358475
# 11870   인천중산초등학교  초등학교      인천광역시 중구 두미포로 100  인천광역시교육청  37.494695  126.565599
# 11871    인천중산중학교   중학교      인천광역시 중구 두미포로 189  인천광역시교육청  37.498222  126.571277
# 11872     해누리중학교   중학교   서울특별시 송파구 송파대로37길 95  서울특별시교육청  37.497612  127.102533
#
# [11873 rows x 6 columns]

# %%
#초등학교만 추출
pre3 = pre2[pre2['학교급구분']=='초등학교']
#서울초등학교
pre4 = pre3[pre3['시도교육청명']=='서울특별시교육청']

# %%
len(pre3)
# Out:
# 6278

# %%
len(pre4)
# Out:
# 603

# %%
# 사고다발 & 초등학교 겹치기
# zoom_start: 배율 1~22
map_osm = folium.Map(location=[37.566651, 126.978428], zoom_start=11.3)
map_osm

for i in skid.index:
    lat = skid.loc[i, '위도']
    lon = skid.loc[i, '경도']
    name = skid.loc[i, '사고지역위치명']
    ser = skid.loc[i, '심각도']
    marker = folium.CircleMarker([lat,lon], radius=int(ser), color='#FFb90F', fill_color='#FFb90F',alpha=1, popup=name)
    marker.add_to(map_osm)

    
for i in pre4.index:
    lat = pre4.loc[i, '위도']
    lon = pre4.loc[i, '경도']
    name = pre4.loc[i, '학교명']
    marker = folium.CircleMarker([lat,lon], radius=1, color='#3186cc', fill_color='#3186cc',alpha=1, popup=name)
    marker.add_to(map_osm)
    
map_osm #징그러워...
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//rawcdn.githack.com/python-visualization/folium/master/folium/templates/leaflet.awesome.rotate.css%22/%3E%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_45ffcce8c4984c19baf47b2c83a250ef%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_45ffcce8c4984c19baf47b2c83a250ef%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_45ffcce8c4984c19baf47b2c83a250ef%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%22map_45ffcce8c4984c19baf47b2c83a250ef%22%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20center%3A%20%5B37.566651%2C%20126.978428%5D%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20% ...

# %%
#3번째 text map save
#map_osm.save('전국_초등학교_분포.html')

# %%
# 사고다발 & 초등학교 겹치기
# zoom_start: 배율 1~22
map_osm = folium.Map(location=[37.566651, 126.978428], zoom_start=11.3)
map_osm

for i in skid.index:
    lat = skid.loc[i, '위도']
    lon = skid.loc[i, '경도']
    name = skid.loc[i, '사고지역위치명']
    ser = skid.loc[i, '심각도']
    marker = folium.CircleMarker([lat,lon], radius=int(ser)*1.3, fill_color='BuFu',alpha=1, popup=name)
    marker.add_to(map_osm)

    
map_osm #징그러워...
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//rawcdn.githack.com/python-visualization/folium/master/folium/templates/leaflet.awesome.rotate.css%22/%3E%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_85a5d53576404bb088813ea9a6537ddb%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_85a5d53576404bb088813ea9a6537ddb%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_85a5d53576404bb088813ea9a6537ddb%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%22map_85a5d53576404bb088813ea9a6537ddb%22%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20center%3A%20%5B37.566651%2C%20126.978428%5D%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20% ...
